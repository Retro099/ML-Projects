# %%
# ===== Github_Quick1 (Secure Version + Auto Verification) =====
# Universal Colab–GitHub one-cell setup script with Colab secrets support
# Designed for Retro099 / ML-Projects

from google.colab import userdata
import os

# --- CONFIG ---
GITHUB_USERNAME = "Retro099"                             # Your GitHub username
GITHUB_REPO = "ML-Projects"                              # Your repository name
PROJECT_FOLDER = "Customer_Churn_Prediction/notebooks"    # Folder you want to work in

# --- GET TOKEN FROM COLAB SECRETS ---
# Add token in Colab: Runtime → Run time secrets → name it "GITHUB_TOKEN"
ACCESS_TOKEN = userdata.get('GITHUB_TOKEN')
if not ACCESS_TOKEN:
    raise ValueError("⚠️ Missing GitHub token. Go to Runtime → Run time secrets → add one named 'GITHUB_TOKEN'.")

# --- SETUP ---
REPO_URL = f"https://{ACCESS_TOKEN}@github.com/{GITHUB_USERNAME}/{GITHUB_REPO}.git"
BASE_PATH = "/content"
REPO_PATH = os.path.join(BASE_PATH, GITHUB_REPO)

if os.path.exists(REPO_PATH):
    # %cd $REPO_PATH
    # !git pull
else:
    # %cd $BASE_PATH
    # !git clone $REPO_URL
    # %cd $REPO_PATH

# --- MOVE INTO PROJECT FOLDER ---
os.makedirs(PROJECT_FOLDER, exist_ok=True)
# %cd $PROJECT_FOLDER

# --- SET GIT IDENTITY ---
# !git config --global user.email "retro099@protonmail.com"
# !git config --global user.name "Retro099"

# --- VERIFY CONNECTION & STRUCTURE ---
print("\n✅ GitHub–Colab connection established successfully.")
print(f"📂 Working inside: {os.getcwd()}")
print("📁 Folder contents:")
# !ls

print("\n🔁 Ready to start coding in:", PROJECT_FOLDER)
# Out:
# /content
# Cloning into 'ML-Projects'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 56 (delta 20), reused 37 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 15.33 KiB | 7.67 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/ML-Projects
# /content/ML-Projects/Customer_Churn_Prediction/notebooks
#
# ✅ GitHub–Colab connection established successfully.
# 📂 Working inside: /content/ML-Projects/Customer_Churn_Prediction/notebooks
# 📁 Folder contents:
# Customer_Churn_Prediction.ipynb
#
# 🔁 Ready to start coding in: Customer_Churn_Prediction/notebooks

# %% [markdown]
# # 🧠 Customer_Churn_Prediction — Starter Notebook
# _Auto-generated 2025-11-04_

# %%
# 🔗 GitHub Quick Connect (Github_Quick1)
import os
from getpass import getpass
username = "Retro099"
repo = "ML-Projects"
pat = getpass("Enter your GitHub token (hidden): ")
remote = f"https://{username}:{pat}@github.com/{username}/{repo}.git"
# !git pull {remote} main || echo "Nothing to pull"
# %cd /content/{repo}/{PROJECT_NAME}
print("✅ Connected to GitHub and ready to work.")

# %% [markdown]
# ## 🧰 1. Setup & Imports
# Install and import all necessary libraries here.

# %%
# !pip install -r ../requirements.txt
import numpy as np, pandas as pd

# %% [markdown]
# ## 📊 2. Exploratory Data Analysis

# %%
# Example
# df = pd.read_csv('../data_sample/sample.csv')
# df.head()

# %% [markdown]
# ## 🧠 3. Model Training

# %%
# Write your training code here

# %% [markdown]
# ## 📈 4. Results & Visualization

# %%
# Example plot
# import matplotlib.pyplot as plt
# plt.plot(history.history['accuracy']);

# %% [markdown]
# ## 🚀 5. Push Results Back to GitHub

# %%
import subprocess, getpass, os
pat = getpass.getpass('Enter GitHub token: ')
username, repo = 'Retro099', 'ML-Projects'
remote = f'https://{username}:{pat}@github.com/{username}/{repo}.git'
subprocess.run(['git','add','.'])
subprocess.run(['git','commit','-m','update notebook Customer_Churn_Prediction'])
subprocess.run(['git','push',remote,'HEAD:main'])

# %%
import os
print("✅ Environment Ready")
print("Current Path:", os.getcwd())
print("Files in directory:")
print(os.listdir())
# Out:
# ✅ Environment Ready
# Current Path: /content/ML-Projects/Customer_Churn_Prediction/notebooks
# Files in directory:
# ['Customer_Churn_Prediction.ipynb']

# %%
# !mkdir -p /content/ML-Projects/Customer_Churn_Prediction/data_sample
# !mkdir -p /content/ML-Projects/Customer_Churn_Prediction/assets

# %%
# !ls -R /content/ML-Projects/Customer_Churn_Prediction
# Out:
# /content/ML-Projects/Customer_Churn_Prediction:
# assets	data_sample  notebooks	README.md  requirements.txt
#
# /content/ML-Projects/Customer_Churn_Prediction/assets:
#
# /content/ML-Projects/Customer_Churn_Prediction/data_sample:
#
# /content/ML-Projects/Customer_Churn_Prediction/notebooks:
# Customer_Churn_Prediction.ipynb

# %%
# %cd /content/ML-Projects
# !git add .
# !git commit -m "chore: reorganized folder structure for Customer_Churn_Prediction"
# !git push origin main
# Out:
# /content/ML-Projects
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !ls -R /content/ML-Projects/Customer_Churn_Prediction
# Out:
# /content/ML-Projects/Customer_Churn_Prediction:
# assets	data_sample  notebooks	README.md  requirements.txt
#
# /content/ML-Projects/Customer_Churn_Prediction/assets:
#
# /content/ML-Projects/Customer_Churn_Prediction/data_sample:
#
# /content/ML-Projects/Customer_Churn_Prediction/notebooks:
# Customer_Churn_Prediction.ipynb

# %%
# %cd /content/ML-Projects
# !git add Customer_Churn_Prediction/assets
# !git add Customer_Churn_Prediction/data_sample
# !git add Customer_Churn_Prediction/notebooks/Customer_Churn_Prediction.ipynb
# !git commit -m "add: data_sample and assets folders for churn project"
# !git push origin main
# Out:
# /content/ML-Projects
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# To https://github.com/Retro099/ML-Projects.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/Retro099/ML-Projects.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# %cd /content/ML-Projects
# !git pull --rebase origin main
# Out:
# /content/ML-Projects
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (15/15), 745.33 KiB | 2.77 MiB/s, done.
# From https://github.com/Retro099/ML-Projects
#  * branch            main       -> FETCH_HEAD
#    5e11341..0dedd8d  main       -> origin/main
# Updating 5e11341..0dedd8d
# Fast-forward
#  .../notebooks/Customer_Churn_Prediction.ipynb      |   193 +
#  .../customer-churn-predictionExperiment.ipynb      | 94341 +++++++++++++++++++
#  2 files changed, 94534 insertions(+)
#  create mode 100644 Customer_Churn_Prediction/notebooks/customer-churn-predictionExperiment.ipynb

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# Create .gitkeep placeholders so Git tracks empty folders
# !touch /content/ML-Projects/Customer_Churn_Prediction/assets/.gitkeep
# !touch /content/ML-Projects/Customer_Churn_Prediction/data_sample/.gitkeep

# Commit and push again
# %cd /content/ML-Projects
# !git add Customer_Churn_Prediction/assets/.gitkeep
# !git add Customer_Churn_Prediction/data_sample/.gitkeep
# !git commit -m "chore: add .gitkeep files to track empty assets and data_sample folders"
# !git push origin main
# Out:
# /content/ML-Projects
# [main 6ad938f] chore: add .gitkeep files to track empty assets and data_sample folders
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 Customer_Churn_Prediction/assets/.gitkeep
#  create mode 100644 Customer_Churn_Prediction/data_sample/.gitkeep
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 514 bytes | 514.00 KiB/s, done.
# Total 5 (delta 1), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Retro099/ML-Projects.git
#    0dedd8d..6ad938f  main -> main
